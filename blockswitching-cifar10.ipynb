# %%
import tensorflow as tf
from keras import layers, models, optimizers, datasets
import numpy as np

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.utils import to_categorical

(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
train_images = train_images.astype('float32') / 255.0
test_images = test_images.astype('float32') / 255.0

# %%
train_labels = to_categorical(train_labels, 10)
test_labels = to_categorical(test_labels, 10)

# %%
base_model = VGG16(weights=None, include_top=False, input_shape=(32, 32, 3))

# %%
base_model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 32, 32, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 16, 16, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 8, 8, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 8, 8, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 4, 4, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 2, 2, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 2, 2, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 2, 2, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 2, 2, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 1, 1, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Load the VGG16 model without the top layers
def create_vgg16():
    base_model = VGG16(weights=None, include_top=False, input_shape=(32, 32, 3))
    base_model = models.Model(inputs=base_model.input, outputs=base_model.layers[-5].output)
    
    model = models.Sequential()
    model.add(base_model)
    
    model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.3))
    
    model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.3))
    
    model.add(layers.Flatten())
    model.add(layers.Dense(512, activation='relu'))
    model.add(layers.Dropout(0.2))
    model.add(layers.Dense(256, activation='relu'))
    model.add(layers.Dropout(0.2))
    model.add(layers.Dense(10, activation='softmax'))
    return model

# %%
# Train multiple sub-models with random initialization
# Number of sub-models
num_models = 4  #@param
sub_models = []

# %%
epochs = 20
batch_size = 256

histories = []

for i in range(num_models):
    model = create_vgg16()
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    history = model.fit(train_images, train_labels, epochs=epochs, batch_size=batch_size, validation_split=0.2)
    sub_models.append(model)
    histories.append(history)
    print(f"model {i+1} training completed.")
# Out:
# Epoch 1/20
#   3/157 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - accuracy: 0.1068 - loss: 2.7242
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1720173308.700737      82 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 44s 134ms/step - accuracy: 0.1761 - loss: 2.1673 - val_accuracy: 0.1481 - val_loss: 2.9113
# Epoch 2/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.2498 - loss: 1.8751 - val_accuracy: 0.1342 - val_loss: 6.9849
# Epoch 3/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.2925 - loss: 1.7912 - val_accuracy: 0.2288 - val_loss: 2.5647
# Epoch 4/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - accuracy: 0.3684 - loss: 1.6095 - val_accuracy: 0.3168 - val_loss: 2.1455
# Epoch 5/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.4241 - loss: 1.4903 - val_accuracy: 0.4496 - val_loss: 1.5232
# Epoch 6/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.5078 - loss: 1.3054 - val_accuracy: 0.5218 - val_loss: 1.3177
# Epoch 7/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.5781 - loss: 1.1497 - val_accuracy: 0.5524 - val_loss: 1.3944
# Epoch 8/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.6382 - loss: 1.0082 - val_accuracy: 0.6332 - val_loss: 1.0605
# Epoch 9/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.6812 - loss: 0.8948 - val_accuracy: 0.6255 - val_loss: 1.0962
# Epoch 10/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.7042 - loss: 0.8230 - val_accuracy: 0.6564 - val_loss: 1.0333
# Epoch 11/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.7498 - loss: 0.7114 - val_accuracy: 0.6842 - val_loss: 0.9362
# Epoch 12/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.7911 - loss: 0.6027 - val_accuracy: 0.6830 - val_loss: 1.0117
# Epoch 13/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.8134 - loss: 0.5414 - val_accuracy: 0.7014 - val_loss: 0.9601
# Epoch 14/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.8411 - loss: 0.4624 - val_accuracy: 0.7254 - val_loss: 0.9031
# Epoch 15/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.8790 - loss: 0.3478 - val_accuracy: 0.7041 - val_loss: 1.0114
# Epoch 16/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.8921 - loss: 0.3148 - val_accuracy: 0.7260 - val_loss: 0.9916
# Epoch 17/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.9095 - loss: 0.2577 - val_accuracy: 0.7224 - val_loss: 1.1087
# Epoch 18/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.9160 - loss: 0.2411 - val_accuracy: 0.7295 - val_loss: 1.1723
# Epoch 19/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.9361 - loss: 0.1888 - val_accuracy: 0.7282 - val_loss: 1.1691
# Epoch 20/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.9481 - loss: 0.1561 - val_accuracy: 0.7350 - val_loss: 1.2496
# model 1 training completed.
# Epoch 1/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 27s 97ms/step - accuracy: 0.1689 - loss: 2.1794 - val_accuracy: 0.2187 - val_loss: 2.0620
# Epoch 2/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.2379 - loss: 1.8823 - val_accuracy: 0.1492 - val_loss: 3.2839
# Epoch 3/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.2689 - loss: 1.8279 - val_accuracy: 0.2196 - val_loss: 2.2552
# Epoch 4/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.3012 - loss: 1.7693 - val_accuracy: 0.3339 - val_loss: 1.6715
# Epoch 5/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.3411 - loss: 1.6437 - val_accuracy: 0.2090 - val_loss: 3.1998
# Epoch 6/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.3744 - loss: 1.5874 - val_accuracy: 0.3438 - val_loss: 1.8597
# Epoch 7/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.4346 - loss: 1.4808 - val_accuracy: 0.3473 - val_loss: 1.8703
# Epoch 8/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.5014 - loss: 1.3489 - val_accuracy: 0.3834 - val_loss: 1.8035
# Epoch 9/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.5494 - loss: 1.2485 - val_accuracy: 0.5607 - val_loss: 1.2215
# Epoch 10/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.5924 - loss: 1.1342 - val_accuracy: 0.5944 - val_loss: 1.1132
# Epoch 11/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.6296 - loss: 1.0507 - val_accuracy: 0.5970 - val_loss: 1.1403
# Epoch 12/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.6642 - loss: 0.9417 - val_accuracy: 0.5803 - val_loss: 1.2736
# Epoch 13/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.7000 - loss: 0.8424 - val_accuracy: 0.6557 - val_loss: 0.9826
# Epoch 14/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.7189 - loss: 0.7934 - val_accuracy: 0.6541 - val_loss: 1.0206
# Epoch 15/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.7619 - loss: 0.6795 - val_accuracy: 0.6945 - val_loss: 0.9526
# Epoch 16/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.7954 - loss: 0.5890 - val_accuracy: 0.6988 - val_loss: 0.9358
# Epoch 17/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.8251 - loss: 0.5052 - val_accuracy: 0.7107 - val_loss: 0.9164
# Epoch 18/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.8263 - loss: 0.5012 - val_accuracy: 0.6880 - val_loss: 1.0499
# Epoch 19/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.8613 - loss: 0.3981 - val_accuracy: 0.7184 - val_loss: 1.0179
# Epoch 20/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.8909 - loss: 0.3164 - val_accuracy: 0.7014 - val_loss: 1.1232
# model 2 training completed.
# Epoch 1/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 27s 96ms/step - accuracy: 0.1700 - loss: 2.1869 - val_accuracy: 0.1003 - val_loss: 10.7161
# Epoch 2/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.2330 - loss: 1.8940 - val_accuracy: 0.1705 - val_loss: 2.6226
# Epoch 3/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.2735 - loss: 1.8284 - val_accuracy: 0.3270 - val_loss: 1.7270
# Epoch 4/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.3226 - loss: 1.7083 - val_accuracy: 0.2229 - val_loss: 2.3786
# Epoch 5/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.3538 - loss: 1.6187 - val_accuracy: 0.3738 - val_loss: 1.5634
# Epoch 6/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.3852 - loss: 1.5548 - val_accuracy: 0.3825 - val_loss: 1.6337
# Epoch 7/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.4417 - loss: 1.4488 - val_accuracy: 0.3645 - val_loss: 1.7665
# Epoch 8/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.4924 - loss: 1.3553 - val_accuracy: 0.4001 - val_loss: 1.7578
# Epoch 9/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.5511 - loss: 1.2439 - val_accuracy: 0.5453 - val_loss: 1.2922
# Epoch 10/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.6100 - loss: 1.0946 - val_accuracy: 0.5970 - val_loss: 1.2022
# Epoch 11/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.6351 - loss: 1.0234 - val_accuracy: 0.6291 - val_loss: 1.0416
# Epoch 12/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.6710 - loss: 0.9319 - val_accuracy: 0.6430 - val_loss: 2.2157
# Epoch 13/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.7079 - loss: 0.8296 - val_accuracy: 0.6810 - val_loss: 0.9222
# Epoch 14/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 0.7394 - loss: 0.7430 - val_accuracy: 0.5864 - val_loss: 1.3203
# Epoch 15/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.7606 - loss: 0.6904 - val_accuracy: 0.6970 - val_loss: 0.9239
# Epoch 16/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.7982 - loss: 0.5865 - val_accuracy: 0.7110 - val_loss: 0.9650
# Epoch 17/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.8315 - loss: 0.4980 - val_accuracy: 0.7293 - val_loss: 0.9475
# Epoch 18/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.8592 - loss: 0.4057 - val_accuracy: 0.7243 - val_loss: 0.9416
# Epoch 19/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.8796 - loss: 0.3461 - val_accuracy: 0.7196 - val_loss: 1.0509
# Epoch 20/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.8958 - loss: 0.3065 - val_accuracy: 0.7128 - val_loss: 1.1224
# model 3 training completed.
# Epoch 1/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 27s 98ms/step - accuracy: 0.1730 - loss: 2.1632 - val_accuracy: 0.1005 - val_loss: 6.1320
# Epoch 2/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.2363 - loss: 1.8799 - val_accuracy: 0.2587 - val_loss: 2.2848
# Epoch 3/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.2920 - loss: 1.7871 - val_accuracy: 0.2773 - val_loss: 2.2444
# Epoch 4/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.3347 - loss: 1.6768 - val_accuracy: 0.3521 - val_loss: 1.6448
# Epoch 5/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.4089 - loss: 1.5231 - val_accuracy: 0.4116 - val_loss: 1.7535
# Epoch 6/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.5019 - loss: 1.3487 - val_accuracy: 0.4903 - val_loss: 1.4440
# Epoch 7/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.5713 - loss: 1.1901 - val_accuracy: 0.5037 - val_loss: 6.9351
# Epoch 8/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 0.6292 - loss: 1.0417 - val_accuracy: 0.6412 - val_loss: 0.9869
# Epoch 9/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.6656 - loss: 0.9332 - val_accuracy: 0.6565 - val_loss: 0.9917
# Epoch 10/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.7074 - loss: 0.8295 - val_accuracy: 0.6827 - val_loss: 0.9009
# Epoch 11/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.7346 - loss: 0.7510 - val_accuracy: 0.6906 - val_loss: 0.9466
# Epoch 12/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.7693 - loss: 0.6567 - val_accuracy: 0.7191 - val_loss: 0.8239
# Epoch 13/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.8025 - loss: 0.5745 - val_accuracy: 0.6543 - val_loss: 1.1775
# Epoch 14/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.8284 - loss: 0.5027 - val_accuracy: 0.7384 - val_loss: 0.8699
# Epoch 15/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.8487 - loss: 0.4327 - val_accuracy: 0.7225 - val_loss: 0.9288
# Epoch 16/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.8751 - loss: 0.3604 - val_accuracy: 0.7382 - val_loss: 0.9032
# Epoch 17/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.8947 - loss: 0.3075 - val_accuracy: 0.7335 - val_loss: 0.9953
# Epoch 18/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.9136 - loss: 0.2582 - val_accuracy: 0.7500 - val_loss: 0.9467
# Epoch 19/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.9211 - loss: 0.2403 - val_accuracy: 0.7436 - val_loss: 1.0927
# Epoch 20/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.9376 - loss: 0.1832 - val_accuracy: 0.7402 - val_loss: 1.1875
# model 4 training completed.

# %%
for i,model in enumerate(sub_models):
    model.save(f"vgg16_cifar10_sub_model_{i}.h5")

# %%
sub_models = []

for i in range(num_models):
    model_path = f"vgg16_cifar10_sub_model_{i}.h5"
    model = models.load_model(model_path)
    sub_models.append(model)
    print(f"Loaded model {model_path}")

print("All models loaded successfully.")
# Out:
# Loaded model vgg16_cifar10_sub_model_0.h5
# Loaded model vgg16_cifar10_sub_model_1.h5
# Loaded model vgg16_cifar10_sub_model_2.h5
# Loaded model vgg16_cifar10_sub_model_3.h5
# All models loaded successfully.

# %%
for i, model in enumerate(sub_models):
    print(f"vgg16_cifar10_sub_model_{i}.h5")
    model.evaluate(test_images,test_labels) 
    print()
# Out:
# vgg16_cifar10_sub_model_0.h5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7327 - loss: 1.2754
#
# vgg16_cifar10_sub_model_1.h5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6914 - loss: 1.1798
#
# vgg16_cifar10_sub_model_2.h5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7165 - loss: 1.1699
#
# vgg16_cifar10_sub_model_3.h5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7371 - loss: 1.2406

# %% [markdown]
# ## Block Switching model

# %%
class RandomSwitch(layers.Layer):
    def __init__(self, num_choices, **kwargs):
        super(RandomSwitch, self).__init__(**kwargs)
        self.num_choices = num_choices

    def call(self, inputs, training=None):
        inputs = tf.stack(inputs, axis=0)
        if training:
            choice = tf.random.uniform(shape=[], minval=0, maxval=self.num_choices, dtype=tf.int32)
            return inputs[choice]
        else:
            return tf.reduce_mean(inputs, axis=0)

def create_block_switching_model(sub_models, input_shape):
    input_layer = layers.Input(shape=input_shape, name='input_layer')
    
    outputs = [model(input_layer) for model in sub_models]
    
    switched_output = RandomSwitch(len(sub_models))(outputs)
    
    x = layers.Flatten()(switched_output)
    x = layers.Dense(512, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    output_layer = layers.Dense(10, activation='softmax')(x)
    
    return models.Model(inputs=input_layer, outputs=output_layer)

# Assuming sub_models is your list of pre-prepared sub-models
input_shape = (32, 32, 3)  # Adjust this to match your data
block_switching_model = create_block_switching_model(sub_models, input_shape)

# %%
block_switching_model.summary()
# Out:
# Model: "functional_283"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential          │ (None, 10)        │  9,508,298 │ input_layer[0][0] │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_1        │ (None, 10)        │  9,508,298 │ input_layer[0][0] │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_2        │ (None, 10)        │  9,508,298 │ input_layer[0][0] │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_3        │ (None, 10)        │  9,508,298 │ input_layer[0][0] │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ random_switch_6     │ (None, 10)        │          0 │ sequential[0][0], │
# │ (RandomSwitch)      │                   │            │ sequential_1[0][… │
# │                     │                   │            │ sequential_2[0][… │
# │                     │                   │            │ sequential_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_10          │ (None, 10)        │          0 │ random_switch_6[… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_30 (Dense)    │ (None, 512)       │      5,632 │ flatten_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_28          │ (None, 512)       │          0 │ dense_30[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_31 (Dense)    │ (None, 256)       │    131,328 │ dropout_28[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_29          │ (None, 256)       │          0 │ dense_31[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_32 (Dense)    │ (None, 10)        │      2,570 │ dropout_29[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 38,172,722 (145.62 MB)
#  Trainable params: 38,169,650 (145.61 MB)
#  Non-trainable params: 3,072 (12.00 KB)

# %%
# Compile the model
optimizer = tf.keras.optimizers.Adam()
loss_fn = tf.keras.losses.CategoricalCrossentropy()
train_acc_metric = tf.keras.metrics.CategoricalAccuracy()
val_acc_metric = tf.keras.metrics.CategoricalAccuracy()

@tf.function
def train_step(x, y):
    with tf.GradientTape() as tape:
        logits = block_switching_model(x, training=True)
        loss_value = loss_fn(y, logits)
    grads = tape.gradient(loss_value, block_switching_model.trainable_weights)
    optimizer.apply_gradients(zip(grads, block_switching_model.trainable_weights))
    train_acc_metric.update_state(y, logits)
    return loss_value

@tf.function
def test_step(x, y):
    val_logits = block_switching_model(x, training=False)
    val_acc_metric.update_state(y, val_logits)

# %%
from tqdm import tqdm

# Training loop
epochs = 10
batch_size = 256

for epoch in range(epochs):
    print(f"\nStart of epoch {epoch+1}")
    
    # Training loop with tqdm progress bar
    train_loss = []
    train_correct = 0
    total_samples = 0
    with tqdm(total=len(train_images)) as pbar:
        for step in range(0, len(train_images), batch_size):
            x_batch = train_images[step:step+batch_size]
            y_batch = train_labels[step:step+batch_size]
            
            with tf.GradientTape() as tape:
                logits = block_switching_model(x_batch, training=True)
                loss_value = loss_fn(y_batch, logits)
            grads = tape.gradient(loss_value, block_switching_model.trainable_weights)
            optimizer.apply_gradients(zip(grads, block_switching_model.trainable_weights))
            
            train_loss.append(loss_value)
            train_correct += tf.reduce_sum(tf.cast(tf.argmax(logits, axis=1) == tf.argmax(y_batch, axis=1), tf.float32))
            total_samples += x_batch.shape[0]
            
            pbar.update(x_batch.shape[0])
            pbar.set_description(f"Training loss: {float(loss_value):.4f}")
    
    avg_train_loss = tf.reduce_mean(train_loss)
    avg_train_acc = train_correct / total_samples
    print(f"Training loss over epoch: {float(avg_train_loss):.4f}, acc: {float(avg_train_acc):.4f}")
    
    # Validation loop with tqdm progress bar
    val_correct = 0
    total_val_samples = 0
    with tqdm(total=len(test_images)) as pbar:
        for step in range(0, len(test_images), batch_size):
            x_batch_val = test_images[step:step+batch_size]
            y_batch_val = test_labels[step:step+batch_size]
            
            val_logits = block_switching_model(x_batch_val, training=False)
            val_correct += tf.reduce_sum(tf.cast(tf.argmax(val_logits, axis=1) == tf.argmax(y_batch_val, axis=1), tf.float32))
            total_val_samples += x_batch_val.shape[0]
            
            pbar.update(x_batch_val.shape[0])
            pbar.set_description(f"Validation acc: {float(val_correct / total_val_samples):.4f}")
    
    avg_val_acc = val_correct / total_val_samples
    print(f"Validation acc: {float(avg_val_acc):.4f}")
# Out:
# Start of epoch 1
# Training loss: 1.1070: 100%|██████████| 50000/50000 [02:52<00:00, 290.23it/s]
# Training loss over epoch: 1.2739, acc: 0.6279
# Validation acc: 0.7161: 100%|██████████| 10000/10000 [00:04<00:00, 2359.99it/s]
# Validation acc: 0.7161
#
# Start of epoch 2
# Training loss: 1.2425: 100%|██████████| 50000/50000 [02:51<00:00, 291.30it/s]
# Training loss over epoch: 0.8985, acc: 0.7138
# Validation acc: 0.7387: 100%|██████████| 10000/10000 [00:04<00:00, 2324.68it/s]
# Validation acc: 0.7387
#
# Start of epoch 3
# Training loss: 0.9848: 100%|██████████| 50000/50000 [02:51<00:00, 290.88it/s]
# Training loss over epoch: 0.8226, acc: 0.7344
# Validation acc: 0.7501: 100%|██████████| 10000/10000 [00:04<00:00, 2308.08it/s]
# Validation acc: 0.7501
#
# Start of epoch 4
# Training loss: 0.9006: 100%|██████████| 50000/50000 [02:53<00:00, 288.05it/s]
# Training loss over epoch: 0.7539, acc: 0.7568
# Validation acc: 0.7555: 100%|██████████| 10000/10000 [00:04<00:00, 2319.99it/s]
# Validation acc: 0.7555
#
# Start of epoch 5
# Training loss: 0.9252: 100%|██████████| 50000/50000 [02:52<00:00, 290.59it/s]
# Training loss over epoch: 0.6803, acc: 0.7803
# Validation acc: 0.7404: 100%|██████████| 10000/10000 [00:04<00:00, 2309.32it/s]
# Validation acc: 0.7404
#
# Start of epoch 6
# Training loss: 0.7742: 100%|██████████| 50000/50000 [02:53<00:00, 288.73it/s]
# Training loss over epoch: 0.6900, acc: 0.7779
# Validation acc: 0.7699: 100%|██████████| 10000/10000 [00:04<00:00, 2293.59it/s]
# Validation acc: 0.7699
#
# Start of epoch 7
# Training loss: 0.6264: 100%|██████████| 50000/50000 [02:52<00:00, 289.77it/s]
# Training loss over epoch: 0.6577, acc: 0.7879
# Validation acc: 0.7721: 100%|██████████| 10000/10000 [00:04<00:00, 2350.36it/s]
# Validation acc: 0.7721
#
# Start of epoch 8
# Training loss: 0.7854: 100%|██████████| 50000/50000 [02:51<00:00, 290.99it/s]
# Training loss over epoch: 0.6357, acc: 0.7952
# Validation acc: 0.7725: 100%|██████████| 10000/10000 [00:04<00:00, 2320.34it/s]
# Validation acc: 0.7725
#
# Start of epoch 9
# Training loss: 0.7456: 100%|██████████| 50000/50000 [02:52<00:00, 290.48it/s]
# Training loss over epoch: 0.6064, acc: 0.8050
# Validation acc: 0.7805: 100%|██████████| 10000/10000 [00:04<00:00, 2323.85it/s]
# Validation acc: 0.7805
#
# Start of epoch 10
# Training loss: 0.5537: 100%|██████████| 50000/50000 [02:52<00:00, 290.55it/s]
# Training loss over epoch: 0.6255, acc: 0.8008
# Validation acc: 0.7704: 100%|██████████| 10000/10000 [00:04<00:00, 2333.65it/s]
# Validation acc: 0.7704

# %%
# Final evaluation on test set
test_acc_metric = tf.keras.metrics.CategoricalAccuracy()

# Initialize variables to store cumulative accuracy
total_samples = len(test_images)
evaluated_samples = 0

# Evaluation loop
for x_batch_test, y_batch_test in zip(test_images, test_labels):
    x_batch_test = tf.expand_dims(x_batch_test, axis=0)  # Add batch dimension
    test_logits = block_switching_model(x_batch_test, training=False)
    test_acc_metric.update_state(y_batch_test, test_logits)
    
    evaluated_samples += 1
    print(f"Evaluated {evaluated_samples}/{total_samples} samples.", end='\r')
    
# Compute and print the final test accuracy
test_acc = test_acc_metric.result()
print(f"\nTest acc: {float(test_acc):.4f}")
# Out:
# Evaluated 10000/10000 samples.
# Test acc: 0.7704

# %%
# Save the model
block_switching_model.save('cifar10_block_switching_model.h5')
print("Model saved successfully.")
# Out:
# Model saved successfully.
